# %% [markdown]
# ## Try 6.7.1: Understanding the penguins dataset with Python.

# %% [markdown]
# **The Python code below loads and summarizes the penguins dataset.**
#
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
penguins = pd.read_csv('palmer_penguins.csv')
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
# Identify the size of the dataset
penguins.shape
# Out:
# (344, 8)

# %%
# Identify the type and number of present values for each feature
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# # Try 6.7.2: Identifying relationships in the penguins dataset with Python.

# %% [markdown]
# **The Python code below creates data visualizations for features in the penguins dataset.**
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Modify the code to explore the relationship between island and species.**

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
# Visualize the relationship between numerical features
plt.rcParams.update({'font.size': 14})
p = sns.pairplot(penguins)
plt.show()

# %%
# Does island affect the relationships?
plt.rcParams.update({'font.size': 14})
p = sns.pairplot(penguins, hue='island', markers=['o', 's', 'v'])
plt.show()

# %%
# Does sex explain the relationships?
plt.rcParams.update({'font.size': 14})
p = sns.pairplot(penguins, hue='sex', markers=['o', 's'])
plt.show()

# %%
# Combine sex and species in a single scatterplot
p = sns.scatterplot(
    data=penguins, x='bill_length_mm', y='body_mass_g', hue='species', style='sex'
)
plt.legend(loc=2, prop={'size': 10})
plt.show()

# %%
# Contingency table for species and sex
pd.crosstab(index=penguins['species'], columns=penguins['sex'])
# Out:
# sex        female  male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %%
# Grouped bar chart for species and sex
p = sns.countplot(data=penguins, x='species', hue='sex', palette='Blues')
plt.legend(loc=1, prop={'size': 10})
plt.show()

# %%
# Contingency table for species and island
pd.crosstab(index=penguins['species'],columns=penguins['island'])
# Out:
# island     Biscoe  Dream  Torgersen
# species
# Adelie         44     56         52
# Chinstrap       0     68          0
# Gentoo        124      0          0

# %%
# Grouped bar chart for species and island
p = sns.countplot(data=penguins, x='species', hue='island', palette='Blues')
plt.legend(loc=2, prop={'size': 10})
plt.show()

# %% [markdown]
# ## Try 6.7.3: Describing distributions in the penguins dataset with Python.

# %% [markdown]
# **The Python code below creates data visualizations for features in the penguins dataset.**
#
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**

# %% [markdown]
# #### DataExploration_PalmerPenguins_03

# %%
# Calculate descriptive statistics for all features
penguins.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    342.000000   333   344.000000
# ...

# %%
# View the distribution of each numerical feature
plt.rcParams["figure.figsize"] = (12, 10)
plt.rcParams.update({'font.size': 14})
penguins.hist()
plt.show()

# %%
sns.reset_orig()

# Distribution of species
p = sns.countplot(data=penguins, x='species',hue='species')
p.set_xlabel('Species', fontsize=14)
p.set_ylabel('Count', fontsize=14)
plt.show()

# %%
# Distribution of bill length by species
p = sns.histplot(data=penguins, x='bill_length_mm', hue='species')
p.set_xlabel('Bill length (mm)', fontsize=14)
p.set_ylabel('Count', fontsize=14)
plt.show()

# %%
# Distribution of bill length by species
p = sns.kdeplot(data=penguins, x='bill_length_mm', hue='species', linewidth=2)
p.set_xlabel('Bill length (mm)', fontsize=14)
p.set_ylabel('Density', fontsize=14)
plt.show()

# %%
# Calculate descriptive statistics by species
penguins[["bill_length_mm", "species"]].groupby(by="species").describe()
# Out:
#           bill_length_mm                                                   \
#                    count       mean       std   min    25%    50%     75%
# species
# Adelie             151.0  38.791391  2.663405  32.1  36.75  38.80  40.750
# Chinstrap           68.0  48.833824  3.339256  40.9  46.35  49.55  51.075
# Gentoo             123.0  47.504878  3.081857  40.9  45.30  47.30  49.550
#
#
#             max
# species
# Adelie     46.0
# Chinstrap  58.0
# Gentoo     59.6

# %% [markdown]
# ## Try 6.7.4: Identifying missing values in the penguins dataset with Python.

# %% [markdown]
# **The Python code below searches features in the penguins dataset for missing values.**
#
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Modify the code to identify penguins with missing values for sex.**

# %%
# Calculate descriptive statistics for bill length
penguins['bill_length_mm'].describe()
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: bill_length_mm, dtype: float64

# %%
# Use pd.isna() to identify missing values for bill length
penguins[pd.isna(penguins['bill_length_mm'])]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 271          NaN  NaN  2009

# %%
# Identify missing values for sex
penguins[pd.isna(penguins['sex'])]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %% [markdown]
# ## Try 6.7.5: Detecting outliers in the penguins dataset with Python.

# %%
# Box plot of bill length by species
p = sns.boxplot(data=penguins, x='bill_length_mm', y='species')
p.set_xlabel('Bill length (mm)', fontsize=14)
p.set_ylabel('Species', fontsize=14)
plt.show()

# %%
# Calculate z-scores of bill length for each species
speciesGroups = penguins.groupby('species')

# z-score = a measure of how far an observation is from the mean
# z-score = (obs-mean)/SD
penguins['bill_length_z'] = speciesGroups['bill_length_mm'].transform(
    lambda x: (x - x.mean()) / x.std()
)

# Sort the result by the largest absolute z-score
penguins.sort_values(by=['bill_length_z'], ascending=False, key=lambda x: abs(x)).head(
    5
)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 185     Gentoo     Biscoe            59.6           17.0              230.0
# 293  Chinstrap      Dream            58.0           17.8              181.0
# 253     Gentoo     Biscoe            55.9           17.0              228.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# 73      Adelie  Torgersen            45.8           18.9              197.0
#
#      body_mass_g     sex  year  bill_length_z
# 185       6050.0    male  2007       3.924621
# 293       3700.0  female  2007       2.744976
# 253       5600.0    male  2009       2.724046
# 19        4200.0    male  2007       2.706539
# 73        4150.0    male  2008       2.631447

# %%
# Box plot of bill depth by species
p = sns.boxplot(data=penguins, x='bill_depth_mm', y='species')
p.set_xlabel('Bill depth (mm)', fontsize=14)
p.set_ylabel('Species', fontsize=14)
plt.show()

# %%
# Calculate z-scores of bill depth for each species
speciesGroups = penguins.groupby('species')

# z-score = a measure of how far an observation is from the mean
# z-score = (obs-mean)/SD
penguins['bill_depth_z'] = speciesGroups['bill_depth_mm'].transform(
    lambda x: (x - x.mean()) / x.std()
)

# Sort the result by the largest absolute z-score
penguins.sort_values(by=['bill_depth_z'], ascending=False, key=lambda x: abs(x)).head(5)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 237  Gentoo     Biscoe            50.8           17.3              228.0
# 189  Gentoo     Biscoe            44.4           17.3              219.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
#
#      body_mass_g   sex  year  bill_length_z  bill_depth_z
# 19        4200.0  male  2007       2.706539      2.592071
# 237       5600.0  male  2009       1.069200      2.362250
# 189       5250.0  male  2008      -1.007470      2.362250
# 49        4150.0  male  2007       1.317340      2.345492
# 13        3800.0  male  2007      -0.071859      2.345492

# %%
# Create a subset containing only Gentoo penguins
gentoo = penguins[penguins['species'] == 'Gentoo']

plt.rcParams["figure.figsize"] = (10, 5)

p = sns.lmplot(
    data=gentoo,
    x='bill_length_mm',
    y='bill_depth_mm',
    scatter_kws={'alpha': 0.3, 'color': '#10a60e'},
    ci=False,
)
p.set_axis_labels('Bill length (mm)', 'Bill depth (mm)', fontsize=14)
plt.plot(59.6, 17, 'go')
# plt.show()
plt.text(59.6 + 0.5, 17, 'A', fontsize=16)
plt.plot(44.4, 17.3, 'go')
plt.text(44.4 + 0.5, 17.3, 'B', fontsize=16)
plt.plot(40.9, 13.7, 'go')
plt.text(40.9 - 1.5, 13.7, 'C', fontsize=16)
plt.show()
